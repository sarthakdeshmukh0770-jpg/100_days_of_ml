# %%
class meremlr:
    def __init__(self):
        self.coff=None
        self.intercept=None
    def fit(self,x_train,y_train):
        x_train = np.insert(x_train,0,1,axis=1)
        betas=np.linalg.inv(np.dot(x_train.T,x_train)).dot(x_train.T).dot(y_train)
        self.coff=betas[1:]
        self.intercept=betas[0]
    def predict(self,x_test):
        y_pred=np.dot(x_test,self.coff) + self.intercept
        return y_pred

# %%
import pandas as pd 
import numpy as np
df=pd.read_csv("cgpa_iq_attendance_lpa_regression.csv")

# %%
df.sample(5)
# Out:
#     cgpa   iq  attendance    lpa
# 35  9.04   90        59.2   8.18
# 95  7.47  132        68.3   7.78
# 85  6.63   81        97.3   7.91
# 1   9.75  118        85.2  10.42
# 99  5.54   85        62.6   5.86

# %%
df.shape
# Out:
# (100, 4)

# %%
x=df.drop(columns=['lpa'])
y=df['lpa']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train_trf=scaler.fit_transform(x_train)
x_test_trf=scaler.transform(x_test)

# %%
x_train_trf
# Out:
# array([[ 1.55852808,  0.23852984,  0.16194472],
#        [ 1.44179083, -0.54721551, -0.43166709],
#        [-0.92042169,  1.3610232 , -1.29240423],
#        [-1.49037413, -1.7819582 ,  1.32690792],
#        [ 1.77826878,  0.91202585, -0.78783419],
#        [-0.97535686,  0.18240517,  0.59231329],
#        [-1.18823066,  0.35077917, -0.50586857],
#        [ 0.18514871,  0.63140251, -0.38714621],
#        [ 0.82377011, -0.54721551, -1.36660571],
#        [-1.58651068,  1.08039986, -0.35746562],
#        [ 1.7233336 ,  0.68752718, -0.60233049],
#        [ 0.17828181, -1.10846219, -1.12916098],
#        [-0.48780719, -1.72583354,  1.46789073],
#        [ 0.4254901 , -1.50133487,  1.26012659],
#        [ 0.32248664, -0.77171418,  1.54951235],
#        [-1.07149342, -0.0420935 , -0.43908724],
#        [-1.12642859, -0.49109084,  0.22872605],
#        [ 0.25381768, -0.0420935 ,  0.52553196],
#        [ 1.16711496, -1.22071153, -1.35918556],
#        [-0.56334305, -1.10846219, -1.61889073],
#        [-0.97535686, -1.66970887,  0.35486857],
#        [ 1.70959981, -0.15434284, -0.86203566],
#        [ 1.36625497, -0.15434284,  0.44391034],
#        [ 0.08901215,  1.13652452, -0.68395212],
#        [ 0.15768112,  1.13652452,  1.41594969],
#        [-0.60454443,  1.47327253,  0.48101108],
#        [ 0.53536045, -0.88396352, -0.73589315],
#        [ 1.09157909,  0.68752718, -0.53554916],
#        [ 1.23578393,  1.47327253,  0.82233787],
#        [-0.87922031,  0.57527785, -1.53726911],
#        [-0.04145889,  0.51915318, -1.21078261],
#        [ 0.44609079,  1.08039986, -0.87687596],
#        [ 0.1920156 , -0.0420935 ,  0.03580221],
#        [ 0.74136735, -0.26659217,  0.44391034],
#        [ 0.45982458,  0.23852984,  0.11742384],
#        [-0.37793684,  0.23852984, -0.02355897],
#        [-1.40797136, -1.6135842 ,  0.44391034],
#        [-0.64574581, -0.0420935 ,  1.16366467],
#        [-0.56334305,  1.41714786,  1.32690792],
#        [ 0.01347629,  0.23852984, -1.61889073],
#        [-1.30496791,  0.01403117,  0.63683418],
#        [-1.23629894, -1.50133487, -1.10690054],
#        [ 0.44609079, -1.33296086, -1.13658113],
#        [ 1.5173267 ,  1.3610232 ,  1.28980718],
#        [ 1.7233336 ,  0.35077917, -1.64115118],
#        [ 1.14651427,  0.46302851, -1.35918556],
#        [-0.53587546,  1.08039986, -1.38886615],
#        [-1.35303619,  1.08039986, -0.44650739],
#        [-0.6732134 , -0.99621285, -0.5874902 ],
#        [-0.13759545, -0.37884151,  1.17108482],
#        [-1.20883136,  0.91202585, -1.01785877],
#        [ 0.09587905,  0.01403117,  0.75555654],
#        [-1.44917275,  0.51915318, -0.92139685],
#        [ 0.26755147,  0.46302851,  1.32690792],
#        [-1.51784171, -0.0420935 , -0.60975064],
#        [-0.93415548,  1.02427519,  0.50327152],
#        [ 0.89930598, -1.72583354,  0.98558112],
#        [-1.38050378,  0.63140251,  0.18420517],
#        [ 1.03664392, -1.72583354,  1.17850496],
#        [-0.48780719,  0.63140251,  0.70361551],
#        [-0.38480373,  1.19264919,  0.49585137],
#        [-0.54274236, -1.72583354, -1.07721995],
#        [-1.27063343,  1.24877386,  1.33432807],
#        [-1.44917275, -0.26659217, -0.81009463],
#        [ 1.65466463,  0.35077917,  0.57005285],
#        [ 1.62033015, -1.38908553,  0.54779241],
#        [-1.12642859, -0.60334018,  0.63683418],
#        [ 0.90617288,  0.91202585,  0.87427891],
#        [-0.35046925, -1.72583354,  1.46047058],
#        [ 0.58342872,  1.19264919,  1.3862691 ],
#        [ 0.8443708 ,  0.01403117, -0.23874325],
#        [ 0.81690322,  0.35077917,  0.43649019],
#        [ 0.89930598, -0.26659217,  1.51241161],
#        [-0.47407339,  1.47327253, -1.58921014],
#        [ 0.49415907,  1.02427519, -1.09206024],
#        [-0.27493338, -0.49109084, -0.87687596],
#        [-0.92728858,  1.41714786,  1.57919294],
#        [-0.98222376, -0.2104675 ,  0.30292753],
#        [ 1.00230943, -1.7819582 ,  1.5569325 ],
#        [ 1.05724461, -1.50133487, -1.32950497]])

# %%
model=meremlr()

# %%
model.fit(x_train_trf,y_train)

# %%
y_pred2=model.predict(x_test_trf)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 from sklearn.metrics import r2_score
# ----> 2 r2_score(y_test,y_pred2)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_regression.py:1288, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#    1284 xp, _, device_ = get_namespace_and_device(y_pred)
#    1285 y_true, sample_weight = move_to(y_true, sample_weight, xp=xp, device=device_)
#    1287 _, y_true, y_pred, sample_weight, multioutput = (
# -> 1288     _check_reg_targets_with_floating_dtype(
#    1289         y_true, y_pred, sample_weight, multioutput, xp=xp
#    1290     )
#    1291 )
#    1293 if _num_samples(y_pred) < 2:
#    1294     msg = "R^2 score is not well-defined with less than two samples."
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_regression.py:209, in _check_reg_targets_with_floating_dtype(y_true, y_pred, sample_weight, multioutput, xp)
#     160 """Ensures y_true, y_pred, and sample_weight correspond to same regression task.
#     161
#     162 Extends `_check_reg_targets` by automatically selecting a suitable floating-point
#    (...)    205     correct keyword.
#     206 """
#     207 dtype_name = _find_matching_floating_dtype(y_true, y_pred, sample_weight, xp=xp)
# --> 209 y_type, y_true, y_pred, sample_weight, multioutput = _check_reg_targets(
#     210     y_true, y_pred, sample_weight, multioutput, dtype=dtype_name, xp=xp
#     211 )
#     213 return y_type, y_true, y_pred, sample_weight, multioutput
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_regression.py:127, in _check_reg_targets(y_true, y_pred, sample_weight, multioutput, dtype, xp)
#     124     y_pred = xp.reshape(y_pred, (-1, 1))
#     126 if y_true.shape[1] != y_pred.shape[1]:
# --> 127     raise ValueError(
#     128         "y_true and y_pred have different number of output ({0}!={1})".format(
#     129             y_true.shape[1], y_pred.shape[1]
#     130         )
#     131     )
#     133 n_outputs = y_true.shape[1]
#     134 allowed_multioutput_str = ("raw_values", "uniform_average", "variance_weighted")
#
# ValueError: y_true and y_pred have different number of output (1!=3)

# %%
model.coff
# Out:
# np.float64(7.925625)
