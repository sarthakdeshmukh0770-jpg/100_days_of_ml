# %%
import pandas as pd 
import requests

# %%
response=requests.get("https://api.themoviedb.org/3/movie/popular?api_key=d1c9d59a2d61e9c42e6dbf0f1d6ce1e2")

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/qeQJx07rK2xm8SD2sJxFKhE7gs0.jpg',
#    'genre_ids': [878, 28, 12],
#    'id': 969681,
#    'title': 'Spider-Man: Brand New Day',
#    'original_language': 'en',
#    'original_title': 'Spider-Man: Brand New Day',
#    'overview': "Fighting crime full-time as Spider-Man in a world that doesn't remember him—and the pressure of seeing his old friends move on without him—sparks a change in Peter Parker he may not have the power to control. But that transformation might also be the only thing that can stop a shocking new threat to the city and those he loves - a powerful villain no one can even see.",
#    'popularity': 1146.6141,
#    'poster_path': '/iPOn6DinuVyLY17YM9mKuPofV08.jpg',
#    'release_date': '2026-07-29',
#    'softcore': False,
#    'video': False,
#    'vote_average': 7.863,
#    'vote_count': 1562},
#   {'adult': False,
#    'backdrop_path': '/RMXG8myu1aGlNUsRjtxzmpdMK0.jpg',
# ...

# %%
dfs=pd.DataFrame(response.json()['results'])[['adult','id','genre_ids','title','original_title','release_date','overview']]

# %%
dfs.shape
# Out:
# (20, 7)

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,5):
    response=requests.get(f"https://api.themoviedb.org/3/movie/popular?api_key=d1c9d59a2d61e9c42e6dbf0f1d6ce1e2&page={i}")
    temp_df=pd.DataFrame(response.json()['results'])[['adult','id','genre_ids','title','original_title','release_date','overview']]
    df=pd.concat([df,temp_df],ignore_index=True)

# %%
df.shape
# Out:
# (80, 7)

# %%
df
# Out:
#     adult       id            genre_ids                      title  \
# 0   False   969681        [878, 28, 12]  Spider-Man: Brand New Day
# 1   False  1368337         [12, 28, 14]                The Odyssey
# 2   False   634649        [28, 12, 878]    Spider-Man: No Way Home
# 3   False  1284041        [27, 878, 53]             The Last House
# 4   False  1081003        [28, 12, 878]                  Supergirl
# ..    ...      ...                  ...                        ...
# 75  False      155         [28, 80, 53]            The Dark Knight
# 76  False  1304313           [27, 9648]     Lee Cronin's The Mummy
# 77  False  1007757  [12, 16, 10751, 14]                    Swapped
# 78  False  1003596        [878, 28, 12]         Avengers: Doomsday
# 79  False     5721                 [18]                     Vixen!
#
#                original_title release_date  \
# 0   Spider-Man: Brand New Day   2026-07-29
# 1                 The Odyssey   2026-07-15
# ...
